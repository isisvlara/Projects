# %% [markdown]
# I should preface that I decided to change my project and focus on detecting Parkinson's Disease (PD). I want to offer a little razzle-dazzle instead of a low-hanging fruit of an idea. I found this project predicting IDC in breast cancer using histology images that I thought about following along with. However, my skills and experience are not quite there yet, nor do I have a machine with the available space for the data. In the Parkinson's project, the dataset is from the UC Irvine Machine Learning Repository, donated in 2008. It holds 195 voice recordings collected from 31 patients, 23 of whom have Parkinson's disease. There is a "status" column holding binary values representing the patient's health: 0 for healthy and 1 for PD.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('parkinsons.data')
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %% [markdown]
# ### EDA
# Performing some eda to better comprehend the data and answer the following questions:
# -What types of variables are there in the dataset?
# -What do their distributions look like?
# -Do you have missing values?
# -Are there redundant features?
# -What are the relationships between the main features?
# -Do you observe outliers?
# -How do the different pairs of features correlate with one another?
# -Do these correlations make sense?
# -What is the relationship between the features and the target?
# -Have you confirmed or rejected your hypothesis?
# -What do you know now that will inform the modeling strategy?

# %% [markdown]
# Changing the file type to CSV because I ran into an error earlier when attempting to look at the shape

# %%
df.to_csv('ParkinsonsDataset.csv', index=False)

# %%
df.shape
# Out:
# (195, 24)

# %% [markdown]
# The variable types in the dataset are object, floating points, and integers

# %%
df.dtypes
# Out:
# name                 object
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# status                int64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object

# %% [markdown]
# There are some normal distributions that appear but most are skewed

# %%
df.hist(bins=15, figsize=(20, 15))
plt.suptitle('Variable Distributions')
plt.show()

# %% [markdown]
# Luckily there are not any missing values

# %%
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %% [markdown]
# I need to lose the first column, or else I can't look at a correlation matrix. Analysis: Quite a few features here show high positive and negative correlations. This means there are some features with a strong relationship that are redundant. I'll have to consider PCA for dimensionality reduction. I also see that my target variable "status" has strong correlations with 'ppe,' 'spread1,' 'MDVP:Shimmer(%),' MDVP:RAP,' and 'Jitter:DDP' indicating these are the features to extract.

# %%
df.drop('name', axis=1, inplace=True)

# %%
import seaborn as sns

corr_matrix = df.corr()

plt.figure(figsize=(16, 12))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Matrix of Features')
plt.show()

# %%
plt.figure(figsize=(20, 15))
df.boxplot(rot=90)
plt.title("Boxplots of Features")
plt.show()

# %% [markdown]
# I have neither confirmed nor denied my hypothesis at this point. If anything, I have changed it quite a few times since I am unsure what features to extract (all except 'name' and the target variable or only the ones with a strong correlation to the target variable. My Inner thought is, "The features will have different effects to the outcome. I suppose conduct a comparative analysis of ml algorithms"), and upon further research, I found one study that selected all features with one ML technique. In contrast, another study selected some features with various ML techniques. I have a lot to consider, but based on these current results, my next steps are dimensionality reduction and validating the importance of the features using XGBoost, Random Forests, Decision Tree, and KNN.
